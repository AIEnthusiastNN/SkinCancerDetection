# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cd /content/drive/MyDrive/SkinCancer/

# %%
# !git clone https://github.com/ngessert/isic2019.git
# Out:
# Cloning into 'isic2019'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 55 (delta 12), reused 46 (delta 9), pack-reused 0
# Unpacking objects: 100% (55/55), done.

# %%
# !cd isic2019
# Out:
# /bin/bash: line 0: cd: isic2019: No such file or directory

# %%
# !pip install pretrainedmodels
# !pip install efficientnet_pytorch
# Out:
# ...
#      |████████████████████████████████| 61kB 3.2MB/s
# ...
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-cp37-none-any.whl size=60963 sha256=d6ca42dc5618a989476f3301d6982474358242bcee3637490d672fa542853385
#   Stored in directory: /root/.cache/pip/wheels/69/df/63/62583c096289713f22db605aa2334de5b591d59861a02c2ecd
# Successfully built pretrainedmodels
# ...
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-cp37-none-any.whl size=16443 sha256=8020954eabc6565b9e77f1163779e6a67a4e45be32539e22fcbf5f75465bc8ec
#   Stored in directory: /root/.cache/pip/wheels/84/27/aa/c46d23c4e8cc72d41283862b1437e0b3ad318417e8ed7d5921
# Successfully built efficientnet-pytorch
# ...

# %%
# !pip install pyunpack

from pyunpack import Archive
Archive('/content/drive/My Drive/data.zip').extractall('/content')
# Out:
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-3b5e5f8a592a> in <module>()
#       2
#       3 from pyunpack import Archive
# ----> 4 Archive('/content/drive/My Drive/data.zip').extractall('/content')
#
# /usr/local/lib/python3.7/dist-packages/pyunpack/__init__.py in extractall(self, directory, auto_create_dir, patool_path)
#      81         directory = _fullpath(directory)
#      82         if not os.path.exists(self.filename):
# ---> 83             raise ValueError("archive file does not exist:" + str(self.filename))
#      84         if not os.path.exists(directory):
#      85             if auto_create_dir:
#
# ValueError: archive file does not exist:/content/drive/My Drive/data.zip

# %%
import torch
cuda  = True if torch.cuda.is_available() else False

# %%
# !python train.py example 2019.test_effb0_ss gpu0
# Out:
# python3: can't open file 'train.py': [Errno 2] No such file or directory

# %%
# !python train.py example 2019.test_effb0_ss_meta gpu0
# Out:
# ['/content//images/official/']
# [0.17851644 0.5082705  0.13118314 0.03422684 0.10358849 0.00943508
#  0.00998776 0.02479176 0.        ]
# final meta shape (25331, 11)
# Len ham 10015
# Train
# (20252,)
# (20252,)
# (20257,)
# (20257,)
# (20251,)
# Val
# (5079,)
# (5079,)
# (5074,)
# (5074,)
# (5080,)
# Devices to use: 0
# Evaluating on validation set during training.
# CV set 0
# cuda:0
# Balance 9
# Current class weights [  5.60066372   1.96640451   7.63362231  29.26589595   9.648404
#  106.03141361 101.26        40.34262948 106.03141361]
# Current class weights with extra [  5.60066372   1.96640451   7.63362231  29.26589595   9.648404
#  106.03141361 101.26        40.34262948 106.03141361]
# scaler mean [5.28876160e+01 1.19790638e-01 2.53505827e-01 1.24086510e-01
#  1.94993087e-01 2.66640332e-03 1.73809994e-01 1.20481928e-02
#  2.02449141e-03 4.54967411e-01 5.27503456e-01] var [3.90614863e+02 1.05440841e-01 1.89240622e-01 1.08689048e-01
# ...
